# %%
from unstructured.partition.pdf import partition_pdf

# %%
file_path = r'C:\Users\amito\PycharmProjects\langraph_scripts\MCP_RAG_BOT\ProvisionalDegree.pdf'

# %%
elements = partition_pdf(
    filename=file_path,
    strategy="auto",
    infer_table_structure=True,
)
# Out:
# No languages specified, defaulting to English.
# Loading weights: 100%|██████████| 367/367 [00:00<00:00, 4530.39it/s]

# %%
total = 0
for el in range(len(elements)):
    total+=1

print(total)
# Out:
# 17

# %%
elements[4].text
# Out:
# 'PROVISIONAL CERTIFICATE'
